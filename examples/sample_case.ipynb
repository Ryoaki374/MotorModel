# %% [markdown]
# # Four-pole sample input case
#
# This notebook replaces the former executable `examples/sample_case.py`. The reusable sample-case factory now lives in the library as `motor_eddy.make_four_pole_sample`, so tests and notebooks can share the same definition without keeping an executable example `.py` file.

# %%
from motor_eddy import make_four_pole_sample

coil, rotor, config = make_four_pole_sample()
coil, rotor, config

# %%
print(f"coil radius = {coil.radius:.4f} m")
print(f"turns = {coil.turns}")
print(f"number of magnets = {len(rotor.magnets)}")
print(f"pole pairs = {rotor.pole_pairs}")
print(f"rotor samples = {config.n_rotor_samples}")
